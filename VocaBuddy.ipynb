# %% [markdown]
# <a href="https://colab.research.google.com/github/Okowa0814/vocabuddy-group-13/blob/main/VocaBuddy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content
# !rm -rf vocabuddy-group-13
# !git clone https://github.com/Okowa0814/vocabuddy-group-13.git
# %cd vocabuddy-group-13
# !ls
# Out:
# /content
# Cloning into 'vocabuddy-group-13'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 15 (delta 5), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (15/15), 5.14 KiB | 2.57 MiB/s, done.
# Resolving deltas: 100% (5/5), done.
# /content/vocabuddy-group-13
# README.md  VocaBuddy.ipynb  vocabularies.json

# %%
import json
from pathlib import Path

ROOT_PATH = Path.cwd()

def load_vocabulary():
	vocabulary_path = ROOT_PATH / "vocabularies.json"
	with vocabulary_path.open(encoding="utf-8") as vocabulary_file:
		return json.load(vocabulary_file)

vocabulary_file = load_vocabulary()

# %%
import random

def ask_question(vocabulary):
	english_word, correct_chinese = random.choice(list(vocabulary.items()))
	chinese_words = list(vocabulary.values())
	wrong_choices = [word for word in chinese_words if word != correct_chinese]
	choices = random.sample(wrong_choices, min(3, len(wrong_choices)))
	choices.append(correct_chinese)
	random.shuffle(choices)

	print(f"\nEnglish word: {english_word}")
	labels = "ABCD"
	for label, choice in zip(labels, choices):
		print(f"{label}. {choice}")

	answer = input("Your answer: ").strip().upper()
	correct_label = labels[choices.index(correct_chinese)]
	if answer == correct_label:
		print("Correct!")
	else:
		print(f"Wrong. The correct answer is {correct_label}.")

	return answer == correct_label

# %%
amount = 10
correct = 0
for i in range(amount):
  is_correct = ask_question(vocabulary_file)
  correct += 1 if is_correct else 0

print(f"Accuracy: {correct}/{amount}")
# Out:
# English word: queue
# A. 最小生成樹
# B. 佇列
# C. 貪婪演算法
# D. 空間複雜度
# Your answer: B
# Correct!
#
# English word: greedy algorithm
# A. 貪婪演算法
# B. 廣度優先搜尋
# C. 指標
# D. 時間複雜度
# Your answer: A
# Correct!
#
# English word: binary search
# A. 指標
# B. 二分搜尋
# C. 最短路徑
# D. 資料結構
# Your answer: B
# Correct!
#
# English word: depth-first search
# A. 圖論
# B. 深度優先搜尋
# C. 佇列
# D. 最小生成樹
# Your answer: A
# Wrong. The correct answer is B.
#
# English word: data structure
# A. 資料結構
# B. 最短路徑
# C. 時間複雜度
# D. 動態規劃
# Your answer: A
# Correct!
#
# English word: array
# A. 走
# B. 時間複雜度
# C. 陣列
# D. 最短路徑
# Your answer: A
# Wrong. The correct answer is C.
#
# English word: Go
# A. 資料結構
# B. 男娘
# C. 走
# D. 陣列
# Your answer: B
# Wrong. The correct answer is C.
#
# English word: graph theory
# A. 鏈結串列
# B. 指標
# C. 資料結構
# D. 圖論
# Your answer: C
# Wrong. The correct answer is D.
#
# English word: Go
# A. 最短路徑
# B. 二分搜尋
# C. 走
# D. 廣度優先搜尋
# Your answer: D
# Wrong. The correct answer is C.
#
# English word: hash table
# A. 鏈結串列
# B. 資料結構
# C. 遞迴
# D. 雜湊表
# Your answer: A
# Wrong. The correct answer is D.
# Accuracy: 4/10
